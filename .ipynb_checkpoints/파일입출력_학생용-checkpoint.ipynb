# %% [markdown]
# # 파일 입출력

# %% [markdown]
# ## 1 정형 데이터

# %% [markdown]
# ### 1.1 EXCEL

# %%
import numpy as np
import pandas as pd
# !pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
엑셀 = pd.read_excel("rawData_sheetplus.xlsx", sheet_name="Sheet1")
엑셀
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
엑셀 = pd.read_excel("rawData_sheetplus.xlsx", sheet_name="Sheet2")
엑셀
# Out:
#    연차    연도       매출       순익  직원수
# 0   1  2021  4000000  1400000   10
# 1   2  2020  3700000  1370000   20
# 2   3  2019  5300000  2000000   30
# 3   4  2018  7000000  2400000   40
# 4   5  2017  8000000  3000000   50
# 5   6  2016  4600000  1870000   60

# %%
# 모든 sheet 다 출력하려면, None!
엑셀 = pd.read_excel("rawData_sheetplus.xlsx", sheet_name=None)
엑셀
# Out:
# {'Sheet1':    연차    연도       매출       순익  직원수
#  0   2  2020  4000000  1400000   40
#  1   4  2018  3700000  1370000   38
#  2   6  2016  5300000  2000000   52
#  3   8  2014  7000000  2400000  100
#  4  10  2012  8000000  3000000  320
#  5   5  2017  4600000  1870000   41,
#  'Sheet2':    연차    연도       매출       순익  직원수
#  0   1  2021  4000000  1400000   10
#  1   2  2020  3700000  1370000   20
#  2   3  2019  5300000  2000000   30
#  3   4  2018  7000000  2400000   40
#  4   5  2017  8000000  3000000   50
#  5   6  2016  4600000  1870000   60}

# %%
type(엑셀)
# Out:
# dict

# %%
type(엑셀['Sheet1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel('rawData_sheetplus.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df['손실'] = [10000, 10000,100000,10000,1000000,1000000]
df
# Out:
#    연차    연도       매출       순익  직원수       손실
# 0   2  2020  4000000  1400000   40    10000
# 1   4  2018  3700000  1370000   38    10000
# 2   6  2016  5300000  2000000   52   100000
# 3   8  2014  7000000  2400000  100    10000
# 4  10  2012  8000000  3000000  320  1000000
# 5   5  2017  4600000  1870000   41  1000000

# %%
df.to_excel("엑셀_내보내기.xlsx", sheet_name="시트_이름이래!")

# %% [markdown]
# ### 1.2 CSV

# %%
df = pd.read_csv("rawData.csv", encoding="cp949")

'''
encoding 종류(자주 사용되는)
utf-8 : 기본
utf-8-sig : 파일 경로에 한글이 있는 경우, 오류 발생 시, 인코딩 방법
cp949 : windows 생성된 파일
'''

df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
df = pd.read_csv("https://paullab.co.kr/titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund_ Mr. Owen Harris    male  22.0      1
# 1    Cumings_ Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen_ Miss. Laina  female  26.0      0
# 3         Futrelle_ Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen_ Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("rawData.csv", encoding='cp949')
df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
df['손실'] = np.nan

# %%
df
# Out:
#    연차    연도        매출       순익  직원수  손실
# 0   1  2015   1000000   100001    1 NaN
# 1   2  2016   2000000   200001    2 NaN
# 2   3  2017   3000000   300001    4 NaN
# 3   4  2018   4000000   400001    8 NaN
# 4   5  2019   8000000   800001   16 NaN
# 5   6  2020  16000000  1600001   32 NaN

# %%
df.to_csv("csv 내보내기.csv")

# %%
# index=False로 인덱스 제외
df.to_csv("csv 내보내기.csv", sep=",", index=False)

# %%
# 불러올 자료가 window에서 만들어진 게 아니라 jupyter에서 만들어진 것 :: utf-8
df = pd.read_csv("csv 내보내기.csv",sep=",", encoding="utf-8")
df
# Out:
#    연차    연도        매출       순익  직원수  손실
# 0   1  2015   1000000   100001    1 NaN
# 1   2  2016   2000000   200001    2 NaN
# 2   3  2017   3000000   300001    4 NaN
# 3   4  2018   4000000   400001    8 NaN
# 4   5  2019   8000000   800001   16 NaN
# 5   6  2020  16000000  1600001   32 NaN

# %% [markdown]
# ### 1.3 TXT

# %%
df = pd.read_table("rawData.txt", encoding="cp949", sep=",")
df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
#  파일 확장자가 .csv라고 무조건 read_csv 사용해야 하는 필요는 X
df = pd.read_csv("rawData.txt", encoding="cp949", sep=",")
df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
df['손실'] = 1000
df
# Out:
#    연차    연도        매출       순익  직원수    손실
# 0   1  2015   1000000   100001    1  1000
# 1   2  2016   2000000   200001    2  1000
# 2   3  2017   3000000   300001    4  1000
# 3   4  2018   4000000   400001    8  1000
# 4   5  2019   8000000   800001   16  1000
# 5   6  2020  16000000  1600001   32  1000

# %%
# 이 밑의 코드들은 직접 txt 파일 열어서 변화되는 걸 볼 수 있다!

# %%
df.to_csv("txt 내보내기.txt")

# %%
check = pd.read_csv("txt 내보내기.txt")
check
# Out:
#    Unnamed: 0  연차    연도        매출       순익  직원수    손실
# 0           0   1  2015   1000000   100001    1  1000
# 1           1   2  2016   2000000   200001    2  1000
# 2           2   3  2017   3000000   300001    4  1000
# 3           3   4  2018   4000000   400001    8  1000
# 4           4   5  2019   8000000   800001   16  1000
# 5           5   6  2020  16000000  1600001   32  1000

# %%
check.to_string('txt 내보내기.txt')

# %%
# !pip install tabulate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
(df.to_markdown("txt 내보내기.txt"))

# %% [markdown]
# ### 1.4 불러오기 공통 속성

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
# header = 1 : 첫번째 row가 header!
df = pd.read_excel('rawData.xlsx', header=1)
df

# 왜 필요해?
# Out:
#    2        2020     4000000  1400000  40
# 0        4     2018  3700000  1370000       38
# 1        6     2016  5300000  2000000       52
# 2        8     2014  7000000  2400000      100
# 3       10     2012  8000000  3000000      320
# 4        5     2017  4600000  1870000       41

# %%
# 이런 경우 필요!
df = pd.read_excel('rawData2.xlsx')
df
# Out:
#   제주도 회사 현황 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        연차         연도         매출         순익        직원수
# 1         2       2020    4000000    1400000         40
# 2         4       2018    3700000    1370000         38
# 3         6       2016    5300000    2000000         52
# 4         8       2014    7000000    2400000        100
# 5        10       2012    8000000    3000000        320
# 6         5       2017    4600000    1870000         41

# %%
df = pd.read_excel('rawData2.xlsx', header=1)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
# header가 없는 경우, names=["~~", "~!" ,,,] 이렇게!

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', index_col='연차')
df
# Out:
#       연도       매출       순익  직원수
# 연차
# 2   2020  4000000  1400000   40
# 4   2018  3700000  1370000   38
# 6   2016  5300000  2000000   52
# 8   2014  7000000  2400000  100
# 10  2012  8000000  3000000  320
# 5   2017  4600000  1870000   41

# %%
# iloc[1]이 index
df = pd.read_excel('rawData.xlsx', index_col=1)
df
# Out:
#       연차       매출       순익  직원수
# 연도
# 2020   2  4000000  1400000   40
# 2018   4  3700000  1370000   38
# 2016   6  5300000  2000000   52
# 2014   8  7000000  2400000  100
# 2012  10  8000000  3000000  320
# 2017   5  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', usecols=['연차','연도'])
df
# Out:
#    연차    연도
# 0   2  2020
# 1   4  2018
# 2   6  2016
# 3   8  2014
# 4  10  2012
# 5   5  2017

# %%
df = pd.read_excel("rawData.xlsx")

# dataframe은 이렇게 읽을 수 없다! 위처럼 usecols 사용해야함
# df['연차','연도']

# %%
df = pd.read_excel("rawData.xlsx", nrows=3)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52

# %%
df = pd.read_excel("rawData.xlsx", skipfooter=2)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100

# %% [markdown]
# ### 1.5 내보내기 공통 속성

# %%
df = pd.read_excel("rawData.xlsx")
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df.to_excel("final.xlsx")

# %%
df.to_excel("final.xlsx", sheet_name="아몰랑", index=None, header=True)

# %%
# index 제거됨. header는 남아있음.
check = pd.read_excel("final.xlsx")
check
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %% [markdown]
# ## 2 반정형 데이터(JSON, XML, HTML 데이터)

# %% [markdown]
# ### 2.1 JSON

# %%
df = pd.read_json('data.json')
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                    thumbnailImg  \
# 0  asset/img/1/thumbnailImg.jpg
# 1  asset/img/2/thumbnailImg.jpg
# 2  asset/img/3/thumbnailImg.jpg
# 3  asset/img/4/thumbnailImg.jpg
# 4  asset/img/5/thumbnailImg.jpg
# 5  asset/img/6/thumbnailImg.jpg
# 6  asset/img/7/thumbnailImg.jpg
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# ...

# %%
df = df.drop(['thumbnailImg'], axis='columns')
# df = df.drop(['thumbnailImg'], axis=1)
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# 2                                                 []             0
# 3                                                 []             0
# 4  [{'id': 1, 'optionName': '13인치', 'additionalFe...            19
# 5  [{'id': 1, 'optionName': '위니브 개발자 스티커팩', 'addi...             0
# ...

# %%
df.to_json('json내보내기.json', indent=4)

# %% [markdown]
# ### 2.2 XML

# %%
df = pd.read_xml("raw_data.xml")
df
# Out:
#      category  id  year    sales   profit  employees
# 0     develop   2  2020  4000000  1400000         40
# 1     develop   4  2018  3700000  1370000         38
# 2     develop   6  2016  5300000  2000000         52
# 3  accounting   8  2014  7000000  2400000        100
# 4  accounting  10  2012  8000000  3000000        320
# 5  accounting   5  2017  4600000  1870000         41

# %%
df = pd.read_xml("https://rss.blog.naver.com/kimilar.xml")
df
# Out:
#    title                                               link  \
# 0  초월한상상  https://blog.naver.com/kimilar?fromRss=true&tr...
#
#                                          description language   generator  \
# 0  반도체관련 업종에 있으며, 전자회로를 마스터하기 위해 노력합니다.\n본 블로그는 I...       ko  Naver Blog
#
#                            pubDate          item
# 0  Mon, 19 Aug 2024 23:47:45 +0900  \n\t\t\t\t\t

# %%
df = pd.read_xml('raw_data.xml', xpath='.//row[year>=2015]')
df
# Out:
#      category  id  year    sales   profit  employees
# 0     develop   2  2020  4000000  1400000         40
# 1     develop   4  2018  3700000  1370000         38
# 2     develop   6  2016  5300000  2000000         52
# 3  accounting   5  2017  4600000  1870000         41

# %%
# elems_only=True를 설정하면 태그와 같은 메타데이터는 무시하고 
# 실제 데이터 요소만 포함된 DataFrame을 생성
df = pd.read_xml('raw_data.xml', elems_only = True)
df
# Out:
#    id  year    sales   profit  employees
# 0   2  2020  4000000  1400000         40
# 1   4  2018  3700000  1370000         38
# 2   6  2016  5300000  2000000         52
# 3   8  2014  7000000  2400000        100
# 4  10  2012  8000000  3000000        320
# 5   5  2017  4600000  1870000         41

# %%
df.to_xml("xml내보내기.xml")

# %%
df.to_xml('xml내보내기', index=True)

# %%
df.to_xml('xml내보내기', root_name="blog")

# %%
df.to_xml('xml내보내기',attr_cols=['id','year','sales'])

# %%
df.to_xml('xml내보내기', xml_declaration=False)

# %% [markdown]
# ### 2.3 HTML

# %%
df = pd.read_html('https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%EA%B5%AC')
df[4]
# Out:
#     연도 (년)   추계인구(명)  출생자수(명)  사망자수(명)  자연증가수(명)  조출생률 (1000명당)  \
# 0     1925  12997611   558897   359042    199855           43.0
# 1     1926  13052741   511667   337948    173719           39.2
# 2     1927  13037169   534524   353818    180706           41.0
# 3     1928  13105131   566142   357701    208441           43.2
# 4     1929  13124279   566969   414366    152603           43.2
# 5     1930  13880469   587144   322611    264533           42.3
# 6     1931  13895052   589428   346800    242628           42.4
# 7     1932  14117191   600545   384287    216258           42.5
# 8     1933  14229277   607021   336232    270789           42.7
# 9     1934  14449155   618135   356515    261620           42.8
# 10    1935  15061960   646158   377454    268704           42.9
# 11    1936  15114775   639355   381806    257549           42.3
# 12    1937  15235383   636839   342575    294264           41.8
# 13    1938  15358193   569299   347025    222274           37.1
# ...

# %%
df[4]['출생자수(명)'].sum()
# Out:
# np.int64(11480088)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 12.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
df = pd.read_html('https://paullab.co.kr/stock.html')
# print(df)

# ####

df = df[3]
# 값이 제대로 들어왔는지 확인하기 위한 코드 (head/tail)
df.head()
df.tail()

# ####

df[['종가']].plot()
# Out:
# <Axes: >
# /home/kimse/.local/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kimse/.local/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/kimse/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/kimse/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_html('html내보내기.html')

# %% [markdown]
# ## 3 비정형 데이터(이미지, 텍스트)

# %% [markdown]
# ### 3.1 이미지

# %%
from PIL import Image  # Correctly import the Image class
import matplotlib.pyplot as plt  # Correctly import pyplot as plt
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# URL of the image
url = 'https://test.api.weniv.co.kr/asset/img/1/thumbnailImg.jpg'

# Fetch the image from the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Open the image using Pillow
    img = Image.open(BytesIO(response.content))
    
    # Display the image using matplotlib
    plt.imshow(img)
    plt.axis('off')  # Hide axes
    plt.show()
else:
    print(f"Failed to retrieve image. Status code: {response.status_code}")

# %%
img.filename
img.format
img.size # width, height
img.mode
img.width, img.height
# Out:
# (510, 510)

# %%
resize_img = img.resize((1020,1020))
resize_img.save("hello.jpg")

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1020x1020>

# %% [markdown]
# ### 3.2 한글 파일
